# %% [markdown]
# <a href="https://colab.research.google.com/github/Ahtesham519/jupyter-notebook_python/blob/main/nlp_via_spacy.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install spacy
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...

# %%
# !python -m spacy download en_core_web_sm
# Out:
# 2023-04-13 11:31:13.943641: I tensorflow/core/platform/cpu_feature_guard.cc:182] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2023-04-13 11:31:15.054753: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 12.8/12.8 MB 54.1 MB/s eta 0:00:00
# ...
# ✔ Download and installation successful
# You can now load the package via spacy.load('en_core_web_sm')

# %%
#import spacy and load the model 
import spacy 
nlp = spacy.load("en_core_web_sm")    #here nlp object refers to the 'en_core_we_sm' Language model instance .

# %%
#assume each sentence in documents corresponds to a seperate document:

documents = ["Dog bites man.", "Man bites dog ."  , "Dog eats meat." , "Man eats food."]
processed_docs = [doc.lower().replace("." , "") for doc in documents]
processed_docs
# Out:
# ['dog bites man', 'man bites dog ', 'dog eats meat', 'man eats food']

# %%
print("Documents After Pre-Processing :" , processed_docs)
# Out:
# Documents After Pre-Processing : ['dog bites man', 'man bites dog ', 'dog eats meat', 'man eats food']

# %%
#Iterate over each document and initiate an nlp instance .
for doc in processed_docs:
  doc_nlp = nlp(doc)  #Creating a spacy "Doc" object which is a container for accessing Linguistic annotations.

  print("-"*30)
  print("Average Vector of '{}' \n".format(doc),doc_nlp.vector)  #This will give the average vector of each document
  for token in doc_nlp:
    print()
    print(token.text, token.vector)  #this gives the text of each word in the doc and their respective vectors.
# Out:
# ------------------------------
# Average Vector of 'dog bites man'
#  [-0.4645846  -0.8704827  -0.8797126   0.5601492   0.21902908 -0.13645978
#   0.44058624  1.827665    0.16126743 -0.18749698  0.7041428  -0.3796244
#  -0.37697935 -0.81970304 -0.6127835   0.70265275 -0.6612517  -0.19193421
#   0.472255    0.08093234 -0.27145305 -0.01265816 -0.5408774  -0.34591904
#   0.48944393  0.2113028   0.01028296  0.63884515  0.22854471 -0.12605749
#  -0.03728535 -0.0155863   0.0091201   0.36559033 -0.84108526 -0.43349206
#   0.26574     0.47921833  0.09730821 -0.16394196 -0.07839262 -0.03694795
#  -0.4529426  -0.08880541 -0.38659295 -0.15151542  0.35047397  0.8556697
#  -0.18897362 -0.16618592  0.10892     0.00644581  0.43828678 -0.4840901
#  -0.01481809  0.0661923   1.2289283  -0.6374825   0.44061872 -0.01362112
#  -0.40318158 -0.42995203 -0.1989394  -0.5829177  -0.31625822 -0.1792578
#   0.17091231  0.3254232  -0.03885905  0.49847683  0.4659768   0.5765772
# ...
