# %% [markdown]
# <a href="https://colab.research.google.com/github/Ahtesham519/jupyter-notebook_python/blob/main/Talentlab_matplotlib.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import matplotlib.pyplot as plt 
from matplotlib.figure import Figure

#Creating a new figure with width = 5 inches 
#and height = 4 inches 
fig = plt.figure(figsize = (5,4))

#Creating first axes for the figure
ax1 = fig.add_axes([0.1, 0.1 , 0.8 , 0.8])

#Creating second axes for the figure 
ax2 = fig.add_axes([0.5 , 0.5 , 0.3 , 0.3])

#Adding the data to be pollted 
ax1.plot([5,4,3,2,1] , [2,3,4,5,6])
ax2.plot([1,2,3,4,5] , [2,3,4,5,6])

plt.show()

# %%
import matplotlib.pyplot as plt

#data to display on plots 
x= [3,1,3]
y= [3,2,1]
z= [1,3,1]
w= [1,3,1]

#creating figure objects 
plt.figure(figsize = (10,10))

#adding first subplot
plt.subplot(231) 
plt.plot(x, y)

#adding second subplot 
plt.subplot(232)
plt.plot(z, y)

#adding third subplot
plt.subplot(233)
plt.plot(z,w)

#adding first subplot
plt.subplot(234)
plt.plot(x,y)

#adding second subplot
plt.subplot(235)
plt.plot(z,y)

#adding third subplot
plt.subplot(236)
plt.plot(z,w)

plt.suptitle("All kinds of line charts")
# Out:
# Text(0.5, 0.98, 'All kinds of line charts')

# %%
import matplotlib.pyplot as plot
fig, axes = plt.subplots(2, 2, figsize = (10,10))

#plotting the data in the 1st subplot
axes[0][0].plot([1,2,3,4] , [1,2,3,4])

#plotting the data in the 1st subplot only 
axes[0][0].plot([1,2,3,4] , [4,3,2,1])

#plotting the data in the 2nd subplot only
axes[0][1].plot([1,2,3,4] , [1,1,1,1])
axes[0][1].plot([1,2,3,4] , [2,1,1,1])

#plotting the data in the 1st subplot
axes[1][0].plot([1,2,3,4] , [1,2,3,4])

#plotting the data in the 1st subplot only
axes[1][0].plot([1,2,3,4] , [4,3,2,1])

#plotting the data in the 2nd subplot only
axes[1][1].plot([1,2,3,4] , [1,1,1,1])
axes[1][1].plot([1,2,3,4] , [2,1,1,1])

# %%
import matplotlib.pyplot as plt
#data to display on plots
x=[3,1,1]
y=[3,2,1]
z=[1,3,1]

#adding the subjects
axes1 = plt.subplot2grid(
    (7,1), (0,0) , rowspan = 2, colspan =1)

axes2 = plt.subplot2grid(
    (7,1) , (2,0) , rowspan = 2, colspan = 1
)

axes3 = plt.subplot2grid(
    (7,1) , (4,0) , rowspan = 2 , colspan=1
)

##This is the code 
axes1.plot(x,y)
axes2.plot(x,z)
axes3.plot(z,y)

# %%
import matplotlib.pyplot as plt
#data to display

x= [3,1,3]
y= [3,2,1]
plt.plot(x,y,c='blue')
plt.plot(y,x,c='orange')

#Adding the legends
plt.legend(["blue" , "orange"] , loc = 'best')
plt.show()

# %%
import seaborn as sns
import matplotlib.pyplot as plt

#Loading the dataset
data = sns.load_dataset("iris")

sns.set_context("notebook")

with sns.axes_style('darkgrid'):
  #adding the subplot
  plt.subplot(211)
  sns.lineplot(x = "sepal_length" , y="sepal_width" , data = data) 

with sns.axes_style('whitegrid'):
  #Adding the subplot
  plt.subplot(212)
  sns.lineplot(x = "sepal_length" , y= "sepal_width" , data = data)

# %% [markdown]
# Color palets

# %%
import seaborn as sns
import matplotlib.pyplot as plt

#current color palette
palette = sns.color_palette()

#plots the color palette as a horizontal array

sns.palplot(palette)

plt.show()

# %%
import seaborn as sns
import matplotlib.pyplot as plt

#current color pallette
palette = sns.color_palette('PiYG' , 10)

#diverging color palette
sns.palplot(palette)

plt.show()

# %%
import seaborn as sns
import matplotlib.pyplot as plt

#loading the dataaset
data = sns.load_dataset('iris')

def plot():
  sns.lineplot(x = "sepal_length" , y= "sepal_width" , data = data)

  #setting the default color palette
sns.set_palette('viridis')
plt.subplot(211)

#plotting with the color palette
plot()

sns.set_palette('vlag')

with sns.axes_style('darkgrid'):
  plt.subplot(212)
  plot()

plt.show()

# %%
import pandas as pd

#create dataframes 
df = pd.DataFrame({
    'x' : [1,1.5 ,3,4,5],
    'y' :[5,15,5,10,2],
    'group' : ['A' , 'other group' , 'B', 'C' , 'D']
})

#basic plot
sns.regplot(data=df , x="x" , y= "y" , fit_reg = True , marker = "o" , color = "skyblue" , scatter_kws = {'s' : 400})

#add annotations one by one with a loop 
for line in range(0 , df.shape[0]):
  plt.text(df.x[line]+ 0.2 , df.y[line] , df.group[line] , size = 'medium', color = 'black' , weight = 'semibold')

plt.show()

# %%
#importing packages
import seaborn as sns
import matplotlib.pyplot as plt

#loading dataset
data = sns.load_dataset("iris")

#Creating a new figure with width - 5 inches 
fig = plt.figure(figsize- (5,4))

#creating the first axes 
ax1 = fig.add_axes([0.1, 0.1 , 0.8, 0.8])

#plotting the graph
sns.lineplot(x="sepal_length"  , y= "sepal_width" , data = data)

#creating second axes for the figure
ax2 = fig.add_axes([0.5, 0.5 , 0.3 , 0.3 ])

#plotting the graph
sns.lineplot(x = "sepal_length" , y= "sepal_width", data = data)
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-11-63212ccaf252> in <cell line: 9>()
#       7
#       8 #Creating a new figure with width - 5 inches
# ----> 9 fig = plt.figure(figsize- (5,4))
#      10
#      11 #creating the first axes
#
# NameError: name 'figsize' is not defined
