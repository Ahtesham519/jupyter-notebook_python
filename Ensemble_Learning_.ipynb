# %% [markdown]
# <a href="https://colab.research.google.com/github/Ahtesham519/jupyter-notebook_python/blob/main/Ensemble_Learning_.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# useful in beautifulfying numpy arrays 

from IPython.display import HTML, display
import tabulate
def pp(a, show_head = True):
  '''
  args :show_head -> if True print only first 5 rows.
  return :none
  '''

  if a.ndim < 2:
    a=[a]
  if show_head:
    display(HTML(tabulate.tabulate(a[:5] , tablefmt = 'html')))
    return
  display(HTML(tabulate.tabulate(a, tablefmt = 'html')))

# %% [markdown]
# Ensemble Learning

# %%
import numpy as np
from sklearn.linear_model import LogisticRegression
from sklearn.naive_bayes import GaussianNB
from sklearn.ensemble  import RandomForestClassifier , VotingClassifier

clf1 = LogisticRegression(multi_class= 'multinomial' , random_state =1)
clf2 = RandomForestClassifier(n_estimators = 50 , random_state =1 )
clf3 = GaussianNB()
X = np.array([[-1 , -1] ,[-2,-1] , [-3, -2 ] , [1,1] , [2,1] , [3, 2] ])
y = np.array([1,1,1,2,2,2])
eclf1 = VotingClassifier(estimators =[('ir' , clf1) , ('rf' , clf2) , ('gnb' , clf3)] , voting='hard')
eclf1 = eclf1.fit(X, y)
pp(eclf1.predict(X))
# Out:
# <table>
# <tbody>
# <tr><td style="text-align: right;">1</td><td style="text-align: right;">1</td><td style="text-align: right;">1</td><td style="text-align: right;">2</td><td style="text-align: right;">2</td><td style="text-align: right;">2</td></tr>
# </tbody>
# </table>

# %% [markdown]
# Stacking

# %%
from sklearn.ensemble import StackingClassifier
from sklearn.ensemble import RandomForestClassifier
from sklearn.svm import LinearSVC
from sklearn.linear_model import LogisticRegression
from sklearn.preprocessing import StandardScaler
from sklearn.pipeline import make_pipeline
from sklearn.ensemble import StackingClassifier

# %%
estimators = [('rf' , RandomForestClassifier(n_estimators = 10 , random_state = 42)) , ('svr' ,make_pipeline(StandardScaler() , LinearSVC(random_state = 42)))]

# %%
s_clf = StackingClassifier(
    estimators = estimators , final_estimator = LogisticRegression()
)

# %%
s_clf
# Out:
# StackingClassifier(estimators=[('rf',
#                                 RandomForestClassifier(n_estimators=10,
#                                                        random_state=42)),
#                                ('svr',
#                                 Pipeline(steps=[('standardscaler',
#                                                  StandardScaler()),
#                                                 ('linearsvc',
#                                                  LinearSVC(random_state=42))]))],
#                    final_estimator=LogisticRegression())

# %% [markdown]
# # Sklearn Random **Forest**

# %%
from sklearn.ensemble import RandomForestClassifier
from sklearn.datasets import make_classification

#Generate a synthetic random datasets with 4 features and 1000 examples(datapoints)

X, y = make_classification(n_samples=1000 , n_features = 4,
                           n_informative =2 , n_redundant = 0,
                           random_state = 0 , shuffle = False
                           )
pp(X)  #features
print('labels: ')
pp(y)  #labels, Binary
# Out:
# <table>
# <tbody>
# <tr><td style="text-align: right;">-1.66853 </td><td style="text-align: right;">-1.29901 </td><td style="text-align: right;"> 0.274647</td><td style="text-align: right;">-0.60362 </td></tr>
# <tr><td style="text-align: right;">-2.97288 </td><td style="text-align: right;">-1.08878 </td><td style="text-align: right;"> 0.70886 </td><td style="text-align: right;"> 0.422819</td></tr>
# <tr><td style="text-align: right;">-0.596141</td><td style="text-align: right;">-1.37007 </td><td style="text-align: right;">-3.11686 </td><td style="text-align: right;"> 0.644452</td></tr>
# <tr><td style="text-align: right;">-1.06895 </td><td style="text-align: right;">-1.17506 </td><td style="text-align: right;">-1.91374 </td><td style="text-align: right;"> 0.663562</td></tr>
# <tr><td style="text-align: right;">-1.30527 </td><td style="text-align: right;">-0.965926</td><td style="text-align: right;">-0.154072</td><td style="text-align: right;"> 1.19361 </td></tr>
# </tbody>
# ...

# %% [markdown]
# Train a random Forest

# %%
#Train a Random Forest
rf_clf = RandomForestClassifier(max_depth = 2 , random_state =0)
rf_clf.fit(X,y)
# Out:
# RandomForestClassifier(max_depth=2, random_state=0)

# %% [markdown]
# Predict label of a random test example

# %%
random_test_example = [[0,1,0.5,0.5]]  #An example with 4 features- in compliance with 
print('predicted label: ')
pp(rf_clf.predict(random_test_example))  #prints 1 as label.
# Out:
# predicted label:
# <table>
# <tbody>
# <tr><td style="text-align: right;">1</td></tr>
# </tbody>
# </table>

# %% [markdown]
# Boosting

# %%
from sklearn.datasets import make_hastie_10_2
from sklearn.ensemble import GradientBoostingClassifier

X,y = make_hastie_10_2(random_state = 0)

# %%
pp(X[:5])    #head of the datasets(featuresa)
# Out:
# <table>
# <tbody>
# <tr><td style="text-align: right;"> 1.76405 </td><td style="text-align: right;"> 0.400157</td><td style="text-align: right;"> 0.978738</td><td style="text-align: right;"> 2.24089 </td><td style="text-align: right;"> 1.86756 </td><td style="text-align: right;">-0.977278</td><td style="text-align: right;"> 0.950088 </td><td style="text-align: right;">-0.151357</td><td style="text-align: right;">-0.103219</td><td style="text-align: right;"> 0.410599</td></tr>
# <tr><td style="text-align: right;"> 0.144044</td><td style="text-align: right;"> 1.45427 </td><td style="text-align: right;"> 0.761038</td><td style="text-align: right;"> 0.121675</td><td style="text-align: right;"> 0.443863</td><td style="text-align: right;"> 0.333674</td><td style="text-align: right;"> 1.49408  </td><td style="text-align: right;">-0.205158</td><td style="text-align: right;"> 0.313068</td><td style="text-align: right;">-0.854096</td></tr>
# ...

# %%
pp(y[:5])  #first 5 labels
# Out:
# <table>
# <tbody>
# <tr><td style="text-align: right;">1</td><td style="text-align: right;">-1</td><td style="text-align: right;">1</td><td style="text-align: right;">-1</td><td style="text-align: right;">1</td></tr>
# </tbody>
# </table>

# %%
training_size = int(len(X) * .8) #20% data for the tezting

# %%
X_train , X_test = X[:training_size] ,X[training_size:]
y_train , y_test = y[:training_size] ,y[training_size:]

#it doesen't overfit easy : 100 is a good number of the trees to use .
gb_clf = GradientBoostingClassifier(n_estimators=100 , learning_rate = 1.0 , max_depth =1 , random_state = 0 )
gb_clf.fit(X_train , y_train)
# Out:
# GradientBoostingClassifier(learning_rate=1.0, max_depth=1, random_state=0)

# %%
gb_clf.score(X_test,y_test)   #score
# Out:
# 0.92375

# %% [markdown]
# Xgboost(Extreme Gradient Boosting

# %%
# !pip3 install xgboost
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...

# %%
import xgboost as xgb

# %%
#labels 0 and 1 instead of -1 and 1 
_y_train = [0 if x== -1 else 1 for x in y_train]
_y_test = [0 if x == -1 else 1 for x in y_test]

# %%
dtrain = xgb.DMatrix(X_train , _y_train)
dtest = xgb.DMatrix(X_test , _y_test)

# %%
dtrain

# %%
param = {'max_depth' : 2, 'eta' :1  ,'objective':'binary:logistic'}
param['nthread'] = 4
param['eval_metric'] = 'auc'

# %%
evalist = [(dtest, 'eval') , (dtrain , 'train')]

# %%
pp(X)
# Out:
# <table>
# <tbody>
# <tr><td style="text-align: right;"> 1.76405 </td><td style="text-align: right;"> 0.400157</td><td style="text-align: right;"> 0.978738</td><td style="text-align: right;"> 2.24089 </td><td style="text-align: right;"> 1.86756 </td><td style="text-align: right;">-0.977278</td><td style="text-align: right;"> 0.950088 </td><td style="text-align: right;">-0.151357</td><td style="text-align: right;">-0.103219</td><td style="text-align: right;"> 0.410599</td></tr>
# <tr><td style="text-align: right;"> 0.144044</td><td style="text-align: right;"> 1.45427 </td><td style="text-align: right;"> 0.761038</td><td style="text-align: right;"> 0.121675</td><td style="text-align: right;"> 0.443863</td><td style="text-align: right;"> 0.333674</td><td style="text-align: right;"> 1.49408  </td><td style="text-align: right;">-0.205158</td><td style="text-align: right;"> 0.313068</td><td style="text-align: right;">-0.854096</td></tr>
# ...

# %%
num_round = 10
bst = xgb.train(param , dtrain , num_round)

# %% [markdown]
# Prediction

# %%
ypred = bst.predict(dtest)

# %%
_ypred = [ 1 if y>0.5 else 0 for y in ypred]
pp(np.asarray(_ypred))
# Out:
# <table>
# <tbody>
# ...

# %% [markdown]
# GPU Support
